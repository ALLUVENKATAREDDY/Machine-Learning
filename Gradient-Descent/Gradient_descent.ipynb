# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [78.35063668]
# 26.15963284313262

# %%
plt.scatter(x, y)
plt.plot(x, reg.predict(x), color='red')
plt.show()

# %%
y_pred = ((78.35 * x) + 0).reshape(4)
type(y_pred)
# Out:
# numpy.ndarray

# %%
plt.scatter(x, y)
plt.plot(x, reg.predict(x), color='red', label='ols')
plt.plot(x, y_pred, color='green', label='gd')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0

slope = -2 * np.sum(y - m * x.ravel() - b)
print(slope)
# Out:
# -209.27763408209216

# %%
lr = 0.1
step_size = lr * slope
print(step_size)
# Out:
# -20.927763408209216

# %%
b = b - step_size
print(b)
# Out:
# 20.927763408209216

# %%
y_pred1 = (78.35 * x) + b

plt.scatter(x, y)
plt.plot(x, reg.predict(x), color='red', label='ols')
plt.plot(x, y_pred, color='green', label='b=0')
plt.plot(x, y_pred1, color='blue', label=f'{b}')
plt.legend()
plt.show()

# %%
# iteration 2
slope = -2 * np.sum(y - m * x.ravel() - b)
print(slope)
# Out:
# -41.85552681641843

# %%
lr = 0.1
step_size = lr * slope
print(step_size)
# Out:
# -4.185552681641844

# %%
b = b - step_size
print(b)
# Out:
# 25.11331608985106

# %%
y_pred2 = (78.35 * x) + b

plt.scatter(x, y)
plt.plot(x, reg.predict(x), color='red', label='ols')
plt.plot(x, y_pred, color='green', label='b=0')
plt.plot(x, y_pred1, color='blue', label='b=-20')
plt.plot(x, y_pred2, color='black', label=f'{b}')
plt.legend()
plt.show()

# %%
# iteration 3
slope = -2 * np.sum(y - m * x.ravel() - b)
print(slope)
# Out:
# -8.371105363283675

# %%
lr = 0.1
step_size = lr * slope
print(step_size)
# Out:
# -0.8371105363283675

# %%
b = b - step_size
print(b)
# Out:
# 25.95042662617943

# %%
y_pred3 = (78.35 * x) + b

plt.scatter(x, y)
plt.plot(x, reg.predict(x), color='red', label='ols')
plt.plot(x, y_pred, color='green', label='b=0')
plt.plot(x, y_pred1, color='blue', label='b=-20')
plt.plot(x, y_pred2, color='black', label='b=25.1')
plt.plot(x, y_pred3, color='brown', label=f'{b}')
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.1
epochs = 10

for i in range(10):
    slope = -2 * np.sum(y - m * x.ravel() - b)
    b = b - lr * slope
    y_pred = m * x + b
    plt.plot(x, y_pred)

plt.scatter(x, y)
plt.show()
